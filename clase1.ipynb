# %% [markdown]
# <a href="https://colab.research.google.com/github/EdgarAntonioDeLeonRamirez/Mineria_de_datos_MCOM/blob/main/clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase - 1: Introduction to Python

# %%
2+3
# Out:
# 5
