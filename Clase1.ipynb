# %% [markdown]
# <a href="https://colab.research.google.com/github/Bloquerto/Mineria_de_datos_MCOM/blob/main/Clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 1 - Data Types

# %%
2+3
# Out:
# 5
